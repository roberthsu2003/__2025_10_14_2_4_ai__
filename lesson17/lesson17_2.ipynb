# %%
import pandas as pd
world_df = pd.read_csv("world.csv")
print(world_df.columns)
print(world_df.info())

# %%
world_df1 = world_df.reindex(columns=['洲名','國家','日期','總確診數','新增確診數','總人口數','解封指數'])
world_df1

# %%
# 使用布林遮罩篩選出「國家」欄位為「台灣」的資料

mask_taiwan = world_df1['國家'] == "台灣"
world_df_taiwan = world_df1[mask_taiwan]
world_df_taiwan

# %%
# 使用DataFrame的query()方法篩選出
world_df_taiwan = world_df1.query("國家 == '台灣'")
world_df_taiwan

# %%
# 篩選出「國家」欄位為「台灣」且「新增確診數」欄位為0的資料
taiwan1 = world_df1.query("國家 == '台灣' and 新增確診數 == 0")
taiwan1

# %%
taiwan_max = world_df_taiwan['新增確診數'].max()
taiwan_max_row = world_df_taiwan.query("新增確診數 == @taiwan_max")
taiwan_max_row
# Out:
#         洲名  國家          日期    總確診數   新增確診數      總人口數   解封指數
# 164835  亞洲  台灣  2022-05-14  699824  128954  23855008  46.24

# %%
world_df_taiwan.query("日期 >= '2022-01-01' and 日期 <= '2022-01-31'")
# Out:
#         洲名  國家          日期   總確診數  新增確診數      總人口數  解封指數
# 164702  亞洲  台灣  2022-01-01  17050     21  23855008  0.21
# 164703  亞洲  台灣  2022-01-02  17070     20  23855008  0.21
# 164704  亞洲  台灣  2022-01-03  17095     25  23855008  0.21
# 164705  亞洲  台灣  2022-01-04  17129     34  23855008  0.21
# 164706  亞洲  台灣  2022-01-05  17155     26  23855008  0.22
# 164707  亞洲  台灣  2022-01-06  17198     43  23855008  0.22
# 164708  亞洲  台灣  2022-01-07  17258     60  23855008  0.22
# 164709  亞洲  台灣  2022-01-08  17302     44  23855008  0.23
# 164710  亞洲  台灣  2022-01-09  17362     60  23855008  0.23
# 164711  亞洲  台灣  2022-01-10  17394     32  23855008  0.23
# 164712  亞洲  台灣  2022-01-11  17463     69  23855008  0.24
# 164713  亞洲  台灣  2022-01-12  17559     96  23855008  0.24
# 164714  亞洲  台灣  2022-01-13  17624     65  23855008  0.25
# 164715  亞洲  台灣  2022-01-14  17692     68  23855008  0.25
# 164716  亞洲  台灣  2022-01-15  17769     77  23855008  0.26
# ...
