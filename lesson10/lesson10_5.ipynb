# %%
class Person:
    def __init__(self,name:str,age:int): #自訂的初始化
        self.name = name
        self.age = age

    #實體方法
    def description(self):
        print(f"我的名字叫{self.name}")
        print(f"我的age是:{self.age}")

# %%
p1 = Person(name="Robert", age=40)
p1.description()
# Out:
# 我的名字叫Robert
# 我的age是:40

# %%
# Student繼承於Person
# Person是父類別
# Student是子類別
class Student(Person):
    pass

# %%
s1 = Student(name="robert",age=40)
s1.description()
# Out:
# 我的名字叫robert
# 我的age是:40
