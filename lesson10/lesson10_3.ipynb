# %%
try:
    raise ValueError
except:
    print("錯誤發生")
print("應用程式結束")
# Out:
# 錯誤發生
# 應用程式結束

# %%
try:
    money = int(input("請輸入金額:"))
    print(money)
except:
    print("出現錯誤")
print("應用程式結束")
# Out:
# 出現錯誤
# 應用程式結束
