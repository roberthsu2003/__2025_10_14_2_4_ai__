# %%
import numpy as np
import pandas as pd

students = np.random.randint(50, high=101, size=(50, 5))
students_df = pd.DataFrame(data=students,
            index=[f"學生{i}" for i in range(1,51)],
            columns=['國文','英文','數學','地理','歷史'])
students_df

# %%
# 透過欄的選取
students_df['國文']
students_df[['英文','地理']]

# %%
# 透過index的選取
students_df.iloc[0]
# Out:
# 國文    51
# 英文    63
# 數學    94
# 地理    78
# 歷史    74
# Name: 學生1, dtype: int64

# %%
# 透過index的選取
students_df.loc['學生1']
# Out:
# 國文    51
# 英文    63
# 數學    94
# 地理    78
# 歷史    74
# Name: 學生1, dtype: int64
