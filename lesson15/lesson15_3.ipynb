# %%
import numpy as np

students = np.random.randint(50, high=101, size=(50, 5))
students.shape
# Out:
# (50, 5)

# %%
# ndarray的實體方法
students.sum(axis=1)
students.mean(axis=1)
# Out:
# array([76.8, 79.4, 79.8, 68.8, 78.2, 80.4, 71.8, 84.2, 81. , 80.4, 63.2,
#        78.6, 70.2, 70.8, 71. , 84.4, 68.6, 78.8, 83. , 67.2, 75.4, 64. ,
#        78. , 74.2, 73.2, 59.8, 74.2, 70.6, 95.2, 71.6, 76.2, 75.6, 81.8,
#        66.6, 70.4, 80.2, 77.8, 75. , 70. , 69.8, 67.2, 81. , 75.8, 77.8,
#        88.6, 80.8, 77.2, 83.6, 70.4, 70.6])

# %%
# numpy內建的函式

np.sum(students, axis=1)
np.mean(students, axis=1)
# Out:
# array([76.8, 79.4, 79.8, 68.8, 78.2, 80.4, 71.8, 84.2, 81. , 80.4, 63.2,
#        78.6, 70.2, 70.8, 71. , 84.4, 68.6, 78.8, 83. , 67.2, 75.4, 64. ,
#        78. , 74.2, 73.2, 59.8, 74.2, 70.6, 95.2, 71.6, 76.2, 75.6, 81.8,
#        66.6, 70.4, 80.2, 77.8, 75. , 70. , 69.8, 67.2, 81. , 75.8, 77.8,
#        88.6, 80.8, 77.2, 83.6, 70.4, 70.6])

# %%
# 1家分站30天的營收

oneStore = np.random.randint(100, 10000, size=(30,))
oneStore
# Out:
# array([2126, 8804, 9772, 7602,  913, 9543, 9795, 3662,  820, 8874,  502,
#        5388, 8121, 3684, 5909, 5040, 7590, 8084, 8414,  376, 9712, 4225,
#         955, 3813, 5257, 5417, 2745,  374, 7891, 1628])

# %%
# 累計每天這家店的營收
import matplotlib.pyplot as plt

oneStoreCum = oneStore.cumsum()
oneStoreCum

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1, 31), oneStoreCum, 'r-')
axes.set_title("one Store shop cumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()

# %%
# 5家店30天的營收

fiveStore = np.random.randint(100, 10000, size=(5, 30))
fiveStore
# Out:
# array([[ 892, 8989, 7564, 1147, 6610, 6742, 5659, 2705, 5622, 3403, 9019,
#         1576, 7174, 1265, 2493, 5000, 2723, 1777,  678, 6150, 9937,  727,
#         9201, 1332, 3223, 6317, 2924, 4898, 6352, 4125],
#        [1374, 2187, 8711, 3486, 8977, 5017, 6305, 1769, 1347, 1955, 2517,
#          133, 8981, 8926, 9685, 9744, 5779, 5527, 2970, 1811, 5837, 4070,
#         9776, 9134, 3982, 7907, 3594, 5951,  224, 9548],
#        [7518, 4915, 4034, 6867, 7201, 4277, 9759, 1766, 4579, 9997, 3101,
#         1614, 6741, 1139, 6840, 8657, 8950, 7082, 4026, 2024, 3467, 1818,
#         4076, 6516, 2643, 4865, 3658, 9844, 1096, 7847],
#        [ 737,  175, 6886, 7478, 7905, 7995, 5948, 1692, 6254,  613, 3149,
#         6581,  145, 5525, 2163,  233, 5947, 2571, 3576, 2817, 2934, 3264,
#         5079, 7049, 7607, 7108, 9046, 4364,  497, 3247],
#        [1366, 9145, 8982,  659, 6538, 2899, 6725, 4724, 6454, 6338, 9712,
#         6226, 2121, 6359, 4583, 3913, 7749, 2527, 2377, 2408, 5120,  433,
#         1310,  201, 1090, 2899, 2446, 7974, 4187, 4691]])

# %%
# 累計每天5家店的營收
fiveStoreCum = fiveStore.cumsum(axis=1)
fiveStoreCum
# Out:
# array([[   892,   9881,  17445,  18592,  25202,  31944,  37603,  40308,
#          45930,  49333,  58352,  59928,  67102,  68367,  70860,  75860,
#          78583,  80360,  81038,  87188,  97125,  97852, 107053, 108385,
#         111608, 117925, 120849, 125747, 132099, 136224],
#        [  1374,   3561,  12272,  15758,  24735,  29752,  36057,  37826,
#          39173,  41128,  43645,  43778,  52759,  61685,  71370,  81114,
#          86893,  92420,  95390,  97201, 103038, 107108, 116884, 126018,
#         130000, 137907, 141501, 147452, 147676, 157224],
#        [  7518,  12433,  16467,  23334,  30535,  34812,  44571,  46337,
#          50916,  60913,  64014,  65628,  72369,  73508,  80348,  89005,
#          97955, 105037, 109063, 111087, 114554, 116372, 120448, 126964,
#         129607, 134472, 138130, 147974, 149070, 156917],
#        [   737,    912,   7798,  15276,  23181,  31176,  37124,  38816,
#          45070,  45683,  48832,  55413,  55558,  61083,  63246,  63479,
#          69426,  71997,  75573,  78390,  81324,  84588,  89667,  96716,
#         104323, 111431, 120477, 124841, 125338, 128585],
#        [  1366,  10511,  19493,  20152,  26690,  29589,  36314,  41038,
#          47492,  53830,  63542,  69768,  71889,  78248,  82831,  86744,
#          94493,  97020,  99397, 101805, 106925, 107358, 108668, 108869,
#         109959, 112858, 115304, 123278, 127465, 132156]])

# %%
# 累計每天這家店的營收
import matplotlib.pyplot as plt

figure = plt.figure(figsize=(10, 5))
axes = figure.add_subplot(1,1,1)
axes.plot(range(1, 31), fiveStoreCum[0], 'r-')
axes.plot(range(1, 31), fiveStoreCum[1], 'y-')
axes.plot(range(1, 31), fiveStoreCum[2], 'g-')
axes.plot(range(1, 31), fiveStoreCum[3], 'm-')
axes.plot(range(1, 31), fiveStoreCum[4], 'c-')
axes.set_title("one Store shop cumsum")
axes.set_xlabel("day")
axes.set_ylabel("money")
plt.show()
