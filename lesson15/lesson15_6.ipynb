# %%
import numpy as np
import pandas as pd

students = np.random.randint(50, high=101, size=(50, 5))
students_df = pd.DataFrame(data=students,
            index=[f"學生{i}" for i in range(1,51)],
            columns=['國文','英文','數學','地理','歷史'])
students_df
# Out:
#       國文   英文   數學   地理   歷史
# 學生1   99   95   73   71   88
# 學生2   77   76   58   78   53
# 學生3   66   85   76   54   90
# 學生4   98   77   80   82   64
# 學生5   64   56   79   60   90
# 學生6   66   68   69   81   85
# 學生7   87   93   65   93   71
# 學生8   50   57   93   61   91
# 學生9   53   93   84   59   65
# 學生10  58   95   85   98   67
# 學生11  77   50   97   85   79
# 學生12  73   52   59   96   98
# 學生13  54   96   99   87   80
# 學生14  79   63   91   89   68
# 學生15  99   63   71   86   95
# 學生16  94   71   67   54   96
# 學生17  96   89   52   72   69
# 學生18  89   85  100   90   60
# 學生19  66   63   94   75   75
# 學生20  92   78   71   88   87
# 學生21  85   77   81   91   50
# 學生22  54   58   92   91   81
# 學生23  53   79   87   78   61
# 學生24  62   81   84   57   64
# 學生25  60   58   61   83   53
# 學生26  99   79   69   57   71
# 學生27  53   74   51   97  100
# 學生28  60   75   99   73   93
# 學生29  70   97   53   59   61
# 學生30  54   67   72   66   78
# 學生31  98   62   71   82   74
# 學生32  89   97   81   51   85
# 學生33  71  100   79   87   90
# 學生34  84   65   83   72   81
# 學生35  85   88   66   53   76
# 學生36  92   82   73   86   73
# 學生37  51   99   86  100   53
# 學生38  62   91   59   85   67
# 學生39  76   92   75   92   83
# 學生40  55   71   60   87   93
# 學生41  88   53   97   69   94
# 學生42  98   56   76   68   58
# 學生43  80   57   85   83   98
# 學生44  54   55   55   65   57
# 學生45  86   90  100   64   92
# 學生46  68   53   69   87   61
# 學生47  50   62   86   87   55
# 學生48  71   62   69   84   91
# 學生49  62   93   50   74   86
# 學生50  85   64   98   85   55

# %%
new_students = students_df.copy()
sum_series = np.sum(students_df,axis=1)
mean_series = np.mean(students_df,axis=1)
new_students['總分'] = sum_series
new_students['平均'] = mean_series
new_students
# Out:
#       國文   英文   數學   地理   歷史   總分    平均
# 學生1   99   95   73   71   88  426  85.2
# 學生2   77   76   58   78   53  342  68.4
# 學生3   66   85   76   54   90  371  74.2
# 學生4   98   77   80   82   64  401  80.2
# 學生5   64   56   79   60   90  349  69.8
# 學生6   66   68   69   81   85  369  73.8
# 學生7   87   93   65   93   71  409  81.8
# 學生8   50   57   93   61   91  352  70.4
# 學生9   53   93   84   59   65  354  70.8
# 學生10  58   95   85   98   67  403  80.6
# 學生11  77   50   97   85   79  388  77.6
# 學生12  73   52   59   96   98  378  75.6
# 學生13  54   96   99   87   80  416  83.2
# 學生14  79   63   91   89   68  390  78.0
# 學生15  99   63   71   86   95  414  82.8
# 學生16  94   71   67   54   96  382  76.4
# 學生17  96   89   52   72   69  378  75.6
# 學生18  89   85  100   90   60  424  84.8
# 學生19  66   63   94   75   75  373  74.6
# 學生20  92   78   71   88   87  416  83.2
# 學生21  85   77   81   91   50  384  76.8
# 學生22  54   58   92   91   81  376  75.2
# 學生23  53   79   87   78   61  358  71.6
# 學生24  62   81   84   57   64  348  69.6
# 學生25  60   58   61   83   53  315  63.0
# 學生26  99   79   69   57   71  375  75.0
# 學生27  53   74   51   97  100  375  75.0
# 學生28  60   75   99   73   93  400  80.0
# 學生29  70   97   53   59   61  340  68.0
# 學生30  54   67   72   66   78  337  67.4
# 學生31  98   62   71   82   74  387  77.4
# 學生32  89   97   81   51   85  403  80.6
# 學生33  71  100   79   87   90  427  85.4
# 學生34  84   65   83   72   81  385  77.0
# 學生35  85   88   66   53   76  368  73.6
# 學生36  92   82   73   86   73  406  81.2
# 學生37  51   99   86  100   53  389  77.8
# 學生38  62   91   59   85   67  364  72.8
# 學生39  76   92   75   92   83  418  83.6
# 學生40  55   71   60   87   93  366  73.2
# 學生41  88   53   97   69   94  401  80.2
# 學生42  98   56   76   68   58  356  71.2
# 學生43  80   57   85   83   98  403  80.6
# 學生44  54   55   55   65   57  286  57.2
# 學生45  86   90  100   64   92  432  86.4
# 學生46  68   53   69   87   61  338  67.6
# 學生47  50   62   86   87   55  340  68.0
# 學生48  71   62   69   84   91  377  75.4
# 學生49  62   93   50   74   86  365  73.0
# 學生50  85   64   98   85   55  387  77.4
