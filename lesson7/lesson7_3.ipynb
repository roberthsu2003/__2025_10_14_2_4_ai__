# %%
cities = ['台北','台中','高雄','台南']
cities
# Out:
# ['台北', '台中', '高雄', '台南']

# %%
# 索引index
cities[-1]
# Out:
# '台南'

# %%
# slice[前面的索引:後面的索引]
# 前面的索引包含,後面的索引不包含
cities[0:1]
cities[0:2]
cities[:2]
cities[2:4]
cities[2:]
# Out:
# ['高雄', '台南']

# %%
greetings = list('Hello World')
greetings[:5]
#greetings[6:]
greetings[-5:]
# Out:
# ['W', 'o', 'r', 'l', 'd']
